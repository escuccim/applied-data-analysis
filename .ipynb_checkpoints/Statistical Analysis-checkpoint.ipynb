# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
N = 100000
val = np.random.random(N)
plt.hist(val, 100, color='r', edgecolor='b')
plt.title("Histogram of random numbers drawn from the Uniform distribution")
plt.show()

# %%
val2 = np.random.randn(N)
plt.hist(val2, 100, color='r', edgecolor='b')
plt.title("Histogram of random numbers drawn from the Gaussian distribution")

# %%
N = 10000 
# define an array of zeros which will holds the sums
x = np.zeros((N))
# define the number of iterations 
it = [1,2, 4, 8]

f = plt.figure(figsize=(18, 10))
for i in range(4):
    subplot = f.add_subplot(2,2,i+1)
    for j in range(N):
        for k in range(it[i]):
            x[j]= x[j]+np.random.random()   
    plt.hist(x, 100, normed=True, color='r', edgecolor='b')
    plt.title('Number of iterations = '+str(i+1))
    plt.setp(subplot.get_yticklabels(), visible=False)

plt.suptitle("Addition of uniform random variables converges to a Gaussian distribution",fontsize=20);
plt.show()

# %%
import numpy as np

val = [78,75,82,70]
np.mean(val)
#76.25
# Out:
# 76.25

# %%
val2=[78,75,82,70,10]
np.mean(val2)
# Out:
# 63.0

# %%
np.median(val)
# 76.5
np.median(val2)
# Out:
# 75.0

# %%
val3=[94, 66, 51,  8, 10, 34, 69, 21, 49, 16, 21, 83, 44, 69, 29,  7, 26,
       77, 90, 53, 58, 84, 45, 14, 41,  7, 47, 86, 24, 48, 71, 71, 34, 86,
       52, 17,  8, 84, 41, 70, 61, 85,  6, 14, 58, 12, 99, 81, 16, 93]

# %%
np.max(val3) - np.min(val3)
# Out:
# 93

# %%
np.std(val3) * np.std(val3)
# Out:
# 828.84000000000026

# %%
y_pos = range(50)
plt.bar(y_pos, val3)
plt.plot((0,50),(49,49),'b')
plt.plot((0,50),(49+29,49+29),'r')
plt.plot((0,50),(49-29,49-29),'r')
plt.show()

# %%
stats.sem(val3)
# Out:
# 4.1127973498357937

# %%
len(val3)
# Out:
# 50

# %%
np.std(val3) / np.sqrt(50)
# Out:
# 4.0714616540009319

# %%
mean= np.mean(val3)
std = np.std(val3)
zscores=[]
for val in val3:
    z = (val-mean)/std
    zscores.append(z)

# %%
plt.bar(y_pos,zscores)
plt.show()

# %%
import numpy as np
import pandas as pd


X = np.random.randn(1,50)
Y = np.random.randn(1,50)

# %%
plt.scatter(X,Y)
plt.show()

# %%
np.corrcoef(X,Y)
# Out:
# array([[ 1.        , -0.04608125],
#        [-0.04608125,  1.        ]])

# %%
plt.scatter(X,-3*X)
plt.show()

# %%
plt.scatter(X,X+Y)
plt.show()

# %%
np.corrcoef(X,X+Y)
# Out:
# array([[ 1.        ,  0.69302438],
#        [ 0.69302438,  1.        ]])

# %%
df = pd.DataFrame(np.random.randn(50, 2), columns=list('XY'))
df.head()
# Out:
#           X         Y
# 0  2.054883 -1.982579
# 1 -1.434961 -0.380882
# 2 -0.099811 -1.647370
# 3  0.824378 -1.122987
# 4 -2.284430  0.713203

# %%
df['X'].corr(df['Y'])
# Out:
# -0.1616149536040595

# %%
t=np.arange(0, 20, 0.2)
X=np.cos(t)
Y=np.sin(t)

# %%
plt.scatter(X,Y)
plt.show()

# %%
np.corrcoef(X,Y)
# Out:
# array([[ 1.        ,  0.03508976],
#        [ 0.03508976,  1.        ]])

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %%
poisson1 = stats.poisson.rvs(mu=55, size=200000)
poisson2 = stats.poisson.rvs(mu=10, size=100000)
population = np.concatenate((poisson1, poisson2))

# %%
population.mean()
# Out:
# 40.009700000000002

# %%
sample= np.random.choice(population, size=1000)

# %%
sample_mean = sample.mean()
sample_mean
# Out:
# 40.219000000000001

# %%
data = (['red']*50000) + (['blue']*30000) + (['green']*10000) + (['white']*10000)

# %%
sample = random.sample(data, 100)  

for color in set(sample):
    print( color + " proportion estimate:" )
    print( sample.count(color)/100 )
# Out:
# green proportion estimate:
# 0.18
# blue proportion estimate:
# 0.25
# white proportion estimate:
# 0.07
# red proportion estimate:
# 0.5

# %%
z = stats.norm.ppf(q = 0.95)
z
# Out:
# 1.6448536269514722

# %%
pop_std = population.std()
pop_std
# Out:
# 22.146434458922126

# %%
margin_of_error = z * (pop_std / np.sqrt(1000))
margin_of_error
# Out:
# 1.1519432181000036

# %%
confidence_interval = (sample_mean - margin_of_error,  sample_mean + margin_of_error) 
confidence_interval
# Out:
# (39.0670567819, 41.370943218100003)

# %%
intervals = []
sample_means = []

for sample in range(10):
    sample = np.random.choice(population, size = 1000)
    sample_mean = sample.mean()
    sample_means.append(sample_mean)
    pop_std = population.std()  
    margin_of_error = z * (pop_std/np.sqrt(1000))
    confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)  
    intervals.append(confidence_interval)

# %%
plt.figure(figsize=(12,9))

plt.errorbar(x=np.arange(0.1, 10, 1), 
             y=sample_means, 
             yerr=[(top-bot)/2 for top,bot in intervals],
             fmt='o')

plt.hlines(xmin=0, xmax=10, y=population.mean(),color="red", label='population mean')
plt.legend()
plt.title('95% confidence intervals for point estimates of the population mean')
plt.show()

# %%
sample_small = np.random.choice(population, size=10)  
sample_small_mean = sample_small.mean()
sample_small_mean
# Out:
# 36.399999999999999

# %%
t = stats.t.ppf(q = 0.95, df=9)
t
# Out:
# 1.8331129326536335

# %%
sigma = sample_small.std() / np.sqrt(10)
margin_of_error = t * sigma
confidence_interval = (sample_small_mean - margin_of_error,  sample_small_mean + margin_of_error)  
confidence_interval
# Out:
# (25.409880260447757, 47.39011973955224)

# %%
stats.t.ppf(q=0.95, df= 999) - stats.norm.ppf(0.95)
# Out:
# 0.0015267184760627828

# %%
stats.t.interval(alpha = 0.95,              # Confidence level
                 df= 9,                     # Degrees of freedom
                 loc = sample_small_mean,   # Sample mean
                 scale = sigma)             # Standard deviation estimate
# Out:
# (22.837617865572703, 49.962382134427294)

# %%
for confidence in (.5, .75, .8, .90, .95):
    confidence_interval = stats.t.interval(alpha = confidence, df= 9, loc = sample_small_mean, scale = sigma)                   
    interval = round(confidence_interval[1] - confidence_interval[0], 2)
    print(confidence, interval)
# Out:
# 0.5 8.43
# 0.75 14.74
# 0.8 16.58
# 0.9 21.98
# 0.95 27.12

# %%
poisson1 = stats.poisson.rvs(mu=55, size=200000)
poisson2 = stats.poisson.rvs(mu=10, size=100000)
population = np.concatenate((poisson1, poisson2))

# %%
test_sample = np.concatenate((stats.poisson.rvs(mu=50, size=200), stats.poisson.rvs(mu=10, size=100)))

# %%
t_statistic, p_value = stats.ttest_1samp(test_sample, popmean=population.mean())
t_statistic
# Out:
# -3.1392927844415404

# %%
p_value
# Out:
# 0.0018627752746320752

# %%
data =pd.DataFrame(['red']*50000 + ['blue']*30000 + ['green']*10000 + ['white']*10000) 
sample = pd.DataFrame(['red']*600 + ['blue']*300 + ['green']*70 + ['white']*60)

# %%
data_count = pd.crosstab(index=data[0], columns="count")
data_count
# Out:
# col_0  count
# 0
# blue   30000
# green  10000
# red    50000
# white  10000

# %%
sample_count= pd.crosstab(index=sample[0], columns="count")
sample_count
# Out:
# col_0  count
# 0
# blue     300
# green     70
# red      600
# white     60

# %%
expected_count = data_count * len(sample) / len(data)
expected_count
# Out:
# col_0  count
# 0
# blue   309.0
# green  103.0
# red    515.0
# white  103.0

# %%
chi_square = ((( sample_count - expected_count)**2) / expected_count).sum()
chi_square
# Out:
# col_0
# count    42.815534
# dtype: float64

# %%
stats.chi2.ppf(q = 0.95, df = 3)
# Out:
# 7.8147279032511765

# %%
p_value = 1 - stats.chi2.cdf(x=chi_square,  df=3)

# %%
data =pd.DataFrame(['red']*50000 + ['blue']*30000 + ['green']*10000 + ['white']*10000)

# %%
poisson1 = stats.poisson.rvs(mu=55, size=200000)
poisson2 = stats.poisson.rvs(mu=10, size=100000)
population = np.concatenate((poisson1, poisson2))

# %%
sample_small = np.random.choice(population, size=1000)

# %%
pop_mean = population.mean()

# %%
t_statistic, p_value = stats.ttest_1samp(sample_small, popmean=population.mean())

# %%
t_statistic
# Out:
# 0.23911275047328404

# %%
p_value
# Out:
# 0.81106719976374864

# %%
df_sample = data.sample(n=1000)

# %%
data_count = pd.crosstab(index=data[0], columns="count")
data_count
# Out:
# col_0  count
# 0
# blue   30000
# green  10000
# red    50000
# white  10000

# %%
sample_count = pd.crosstab(index=df_sample[0], columns="count")

# %%
expected_count = data_count * len(sample) / len(data)
expected_count
# Out:
# col_0  count
# 0
# blue   309.0
# green  103.0
# red    515.0
# white  103.0

# %%
chi_square = ((( sample_count - expected_count)**2) / expected_count).sum()
chi_square
# Out:
# col_0
# count    2.195469
# dtype: float64

# %%
p_value = 1 - stats.chi2.cdf(x=chi_square,  df=3)
p_value
# Out:
# array([ 0.53284134])

# %%
results = np.array([[120, 80],[190, 10]])

# %%
chi_square, p_value, df, matrix = stats.chi2_contingency(observed=results)

# %%
chi_square, p_value
# Out:
# (68.258064516129025, 1.4343921726783568e-16)

# %%
p_value
# Out:
# 0.24377218200682121

# %%
df
# Out:
# 1

# %%
matrix
# Out:
# array([[ 125.71428571,   74.28571429],
#        [  94.28571429,   55.71428571]])

# %%
np.var(val3)
# Out:
# 828.84000000000015
