# %%
import pandas as pd
import numpy as np

s=pd.Series(['0', 'John Wood', 'Colin Welsh', 'my list', '02456', np.nan, 'HELLO WORLD', 'water%'])
s
# Out:
# 0              0
# 1      John Wood
# 2    Colin Welsh
# 3        my list
# 4          02456
# 5            NaN
# 6    HELLO WORLD
# 7         water%
# dtype: object

# %%
s.str.lower()
# Out:
# 0              0
# 1      john wood
# 2    colin welsh
# 3        my list
# 4          02456
# 5            NaN
# 6    hello world
# 7         water%
# dtype: object

# %%
s.str.upper()
# Out:
# 0              0
# 1      JOHN WOOD
# 2    COLIN WELSH
# 3        MY LIST
# 4          02456
# 5            NaN
# 6    HELLO WORLD
# 7         WATER%
# dtype: object

# %%
s.str.len()
# Out:
# 0     1.0
# 1     9.0
# 2    11.0
# 3     7.0
# 4     5.0
# 5     NaN
# 6    11.0
# 7     6.0
# dtype: float64

# %%
s.str.split(' ')
# Out:
# 0               [0]
# 1      [John, Wood]
# 2    [Colin, Welsh]
# 3        [my, list]
# 4           [02456]
# 5               NaN
# 6    [HELLO, WORLD]
# 7          [water%]
# dtype: object

# %%
substrings = s.str.split(' ', expand=True)

# %%
substrings
# Out:
#         0      1
# 0       0   None
# 1    John   Wood
# 2   Colin  Welsh
# 3      my   list
# 4   02456   None
# 5     NaN   None
# 6   HELLO  WORLD
# 7  water%   None

# %%
substrings[0]
# Out:
# 0         0
# 1      John
# 2     Colin
# 3        my
# 4     02456
# 5       NaN
# 6     HELLO
# 7    water%
# Name: 0, dtype: object

# %%
s.str.replace('%',' percent ')
# Out:
# 0                 0
# 1         John Wood
# 2       Colin Welsh
# 3           my list
# 4             02456
# 5               NaN
# 6       HELLO WORLD
# 7    water percent
# dtype: object

# %%
s.str.split('%')
# Out:
# 0              [0]
# 1      [John Wood]
# 2    [Colin Welsh]
# 3        [my list]
# 4          [02456]
# 5              NaN
# 6    [HELLO WORLD]
# 7        [water, ]
# dtype: object

# %%
s.str.slice_replace(0,2, '___')
# Out:
# 0             ___
# 1      ___hn Wood
# 2    ___lin Welsh
# 3        ___ list
# 4          ___456
# 5             NaN
# 6    ___LLO WORLD
# 7         ___ter%
# dtype: object

# %%
flag = s.str.contains('0')
flag
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5      NaN
# 6    False
# 7    False
# dtype: object

# %%
flag = s.str.contains('0', na=False)
flag
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
genres=movies.genres

# %%
genres[0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
def transform(s):
    s=s.str.strip('[]')
    s=s.str.replace('\{','')
    s=s.str.replace('\}','')
    s=s.str.replace('\,','')
    s=s.str.replace('\"id\":','')
    s=s.str.replace('\"name\":','')
    s=s.str.replace('"','')
    s=s.str.replace('0','')
    s=s.str.replace('1','')
    s=s.str.replace('2','')
    s=s.str.replace('3','')
    s=s.str.replace('4','')
    s=s.str.replace('5','')
    s=s.str.replace('6','')
    s=s.str.replace('7','')
    s=s.str.replace('8','')
    s=s.str.replace('9','')
    s=s.str.replace('    ',', ')
    s=s.str.replace('   ','')
    return s

# %%
genres= transform(genres)
genres[0]
# Out:
# 'Action, Adventure, Fantasy, Science Fiction'

# %%
movies.genres=genres

# %%
movies.loc[:,['title','genres']].head(10)
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
# 5                              Spider-Man 3
# 6                                   Tangled
# 7                   Avengers: Age of Ultron
# 8    Harry Potter and the Half-Blood Prince
# 9        Batman v Superman: Dawn of Justice
#
#                                         genres
# 0  Action, Adventure, Fantasy, Science Fiction
# 1                   Adventure, Fantasy, Action
# 2                     Action, Adventure, Crime
# 3               Action, Crime, Drama, Thriller
# 4           Action, Adventure, Science Fiction
# 5                   Fantasy, Action, Adventure
# 6                            Animation, Family
# 7           Action, Adventure, Science Fiction
# 8                   Adventure, Fantasy, Family
# 9                   Action, Adventure, Fantasy

# %%
movies.keywords[0]
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
keywords = movies.keywords

# %%
def transform(s):
    s=s.str.strip('[]')
    s=s.str.replace('\{','')
    s=s.str.replace('\}','')
    s=s.str.replace('\"id\": [0-9]+','')
    s=s.str.replace('\"name\":','')
    s=s.str.replace('"','')
    s=s.str.replace('\,  ','')
    s=s.str.replace('    ',', ')
    s=s.str.replace('   ','')
    return s

# %%
s=pd.Series(['0', 'John Wood', 'Colin Welsh', 'my list', '02456', np.nan, 'HELLO WORLD', 'water%'])

# %%
s.str.contains('John')
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5      NaN
# 6    False
# 7    False
# dtype: object

# %%
s.str.contains('John|Colin')
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4    False
# 5      NaN
# 6    False
# 7    False
# dtype: object

# %%
s2 = pd.Series(['bar', 'sugar', 'cartoon', 'argon'])

# %%
s2.str.contains(".ar")
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# dtype: bool

# %%
s3= pd.Series(['forest', 'o', 'ff', 'foo', 'fof'])
s3.str.contains("f+o?f+")
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
s4= pd.Series(['Monday5km', 'Wednesday10km', 'Saturday25km'])

# %%
s4.str.extract('(\w+day)',expand=True)
# Out:
#            0
# 0     Monday
# 1  Wednesday
# 2   Saturday

# %%
def f(x):
    return x.groups()[0][:3]

# %%
s4.str.replace('(\w+day)',f)
# Out:
# 0     Mon5km
# 1    Wed10km
# 2    Sat25km
# dtype: object

# %%
meal_plan = ['Monday: 9:12am – Omelet,  3:30pm– Apple slices with almond butter', 
             'Tuesday: 9:35am – Banana bread, 11:00am –Sauteed veggies, 7:02pm– Taco pie',
             'Wednesday: 9:00am – Banana pancakes',  
             'Thursday: 7:23pm– Slow cooker pulled pork', 'Friday: 3:30pm – Can of tuna', 
             'Saturday: 9:11am: Eggs and sweet potato hash browns, 3:22pm: Almonds', 
             'Sunday: 11:00am: Meat and veggie stir fry']

# %%
df = pd.DataFrame(meal_plan, columns=['text'])
df
# Out:
#                                                 text
# 0  Monday: 9:12am – Omelet,  3:30pm– Apple slices...
# 1  Tuesday: 9:35am – Banana bread, 11:00am –Saute...
# 2                Wednesday: 9:00am – Banana pancakes
# 3          Thursday: 7:23pm– Slow cooker pulled pork
# 4                       Friday: 3:30pm – Can of tuna
# 5  Saturday: 9:11am: Eggs and sweet potato hash b...
# 6          Sunday: 11:00am: Meat and veggie stir fry

# %%
time = df.text.str.extractall('(\d?\d+):(\d\d)([ap]m)')

# %%
days = ["Mon","Tue","Wed","Thu","Fri","Sat","Sun"]

# %%
meals = ["breakfast","lunch","dinner"]

# %%
time.index.set_levels([days,meals], inplace=True)

# %%
time.index.set_names(["Day","Meal"], inplace=True)

# %%
time.columns=["Hour","Minute","Period"]

# %%
time
# Out:
#               Hour Minute Period
# Day Meal
# Mon breakfast    9     12     am
#     lunch        3     30     pm
# Tue breakfast    9     35     am
#     lunch       11     00     am
#     dinner       7     02     pm
# Wed breakfast    9     00     am
# Thu breakfast    7     23     pm
# Fri breakfast    3     30     pm
# Sat breakfast    9     11     am
#     lunch        3     22     pm
# Sun breakfast   11     00     am

# %%
time
# Out:
#                 0   1   2
#     match
# Mon breakfast   9  12  am
#     lunch       3  30  pm
# Tue breakfast   9  35  am
#     lunch      11  00  am
#     dinner      7  02  pm
# Wed breakfast   9  00  am
# Thu breakfast   7  23  pm
# Fri breakfast   3  30  pm
# Sat breakfast   9  11  am
#     lunch       3  22  pm
# Sun breakfast  11  00  am

# %%
time
# Out:
#           0   1   2
#   match
# 0 0       9  12  am
#   1       3  30  pm
# 1 0       9  35  am
#   1      11  00  am
#   2       7  02  pm
# 2 0       9  00  am
# 3 0       7  23  pm
# 4 0       3  30  pm
# 5 0       9  11  am
#   1       3  22  pm
# 6 0      11  00  am

# %%
index = pd.MultiIndex[levels=['Monday','Tuesday']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-ca317e83c552> in <module>()
# ----> 1 data = pd.DataFrame(hours,minutes,period)
#
# ~\Anaconda2\envs\exts-ada\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     271         if isinstance(data, BlockManager):
#     272             mgr = self._init_mgr(data, axes=dict(index=index, columns=columns),
# --> 273                                  dtype=dtype, copy=copy)
#     274         elif isinstance(data, dict):
#     275             mgr = self._init_dict(data, index, columns, dtype=dtype)
#
# ~\Anaconda2\envs\exts-ada\lib\site-packages\pandas\core\generic.py in _init_mgr(self, mgr, axes, dtype, copy)
#     163                 mgr = mgr.reindex_axis(axe,
#     164                                        axis=self._get_block_manager_axis(a),
# --> 165                                        copy=False)
#     166
#     167         # make a copy if explicitly requested
#
# ~\Anaconda2\envs\exts-ada\lib\site-packages\pandas\core\internals.py in reindex_axis(self, new_index, axis, method, limit, fill_value, copy)
#    3853         new_index = _ensure_index(new_index)
#    3854         new_index, indexer = self.axes[axis].reindex(new_index, method=method,
# -> 3855                                                      limit=limit)
#    3856
#    3857         return self.reindex_indexer(new_index, indexer, axis=axis,
#
# ~\Anaconda2\envs\exts-ada\lib\site-packages\pandas\core\indexes\multi.py in reindex(self, target, method, level, limit, tolerance)
#    1859                     indexer = self.get_indexer(target, method=method,
#    1860                                                limit=limit,
# -> 1861                                                tolerance=tolerance)
#    1862                 else:
#    1863                     raise Exception("cannot handle a non-unique multi-index!")
#
# ~\Anaconda2\envs\exts-ada\lib\site-packages\pandas\core\indexes\multi.py in get_indexer(self, target, method, limit, tolerance)
#    1805             # we may not compare equally because of hashing if we
#    1806             # don't have the same dtypes
# -> 1807             if self._inferred_type_levels != target._inferred_type_levels:
#    1808                 return Index(self.values).get_indexer(target.values)
#    1809
#
# AttributeError: 'Index' object has no attribute '_inferred_type_levels'

# %%
minutes
# Out:
#           0
#   match
# 0 0      12
#   1      30
# 1 0      35
#   1      00
#   2      02
# 2 0      00
# 3 0      23
# 4 0      30
# 5 0      11
#   1      22
# 6 0      00

# %%
# Out:
# 'culture clash, future, space war, space colony, society, space travel, futuristic, romance, space, alien, tribe, alien planet, cgi, marine, soldier, battle, love affair, anti war, power relations, mind and soul, 3d'

# %%
keywords[0]
# Out:
# 'id: 1463  culture clash id: 2964  future id: 3386  space war id: 3388  space colony id: 3679  society id: 3801  space travel id: 9685  futuristic id: 9840  romance id: 9882  space id: 9951  alien id: 10148  tribe id: 10158  alien planet id: 10987  cgi id: 11399  marine id: 13065  soldier id: 14643  battle id: 14720  love affair id: 165431  anti war id: 193554  power relations id: 206690  mind and soul id: 209714  3d'

# %%
keywords = transform(keywords)

# %%
keywords
# Out:
# 0                        culture clash  future  space war
# 1                        ocean  drug abuse  exotic island
# 2                       spy  based on novel  secret agent
# 3                     dc comics  crime fighter  terrorist
# 4                         based on novel  mars  medallion
# 5                       dual identity  amnesia  sandstorm
# 6                                   hostage  magic  horse
# 7                         marvel comic  sequel  superhero
# 8                                     witch  magic  broom
# 9                         dc comics  vigilante  superhero
# 10           saving the world  dc comics  invulnerability
# 11                      killing  undercover  secret agent
# 12                         witch  fortune teller  bondage
# 13                                 texas  horse  survivor
# 14                 saving the world  dc comics  superhero
# 15      based on novel  fictional place  brother siste...
# 16                         new york  shield  marvel comic
# 17                                   sea  captain  mutiny
# 18                       time travel  time machine  alien
# 19                             corruption  elves  dwarves
# 20                       loss of father  vigilante  serum
# 21                             robin hood  archer  knight
# 22                                   elves  dwarves  orcs
# 23                           england  compass  experiment
# 24               film business  screenplay  show business
# 25                               shipwreck  iceberg  ship
# 26                           civil war  war  marvel comic
# 27                         fight  u.s. navy  mind reading
# 28                        monster  dna  tyrannosaurus rex
# 29                           spy  secret agent  sociopath
#                               ...
# 4773               salesclerk  loser  aftercreditsstinger
# 4774                                                  NaN
# 4775                                                  NaN
# 4776                       office  love  independent film
# 4777                                                  NaN
# 4778                     rampage  massacre  killing spree
# 4779                            moon  philosophy  burglar
# 4780                                                  NaN
# 4781                           dating  divorce  sex scene
# 4782       christianity  father son relationship  georgia
# 4783                                                  NaN
# 4784                                                  NaN
# 4785                                                  NaN
# 4786                                                  NaN
# 4787                                                  NaN
# 4788                       gay  trailer park  pop culture
# 4789     addiction  recovering drug addict  estranged son
# 4790                                                  NaN
# 4791                                                  NaN
# 4792                             japan  prostitute  hotel
# 4793                      confession  hazing  gang member
# 4794                                                  NaN
# 4795                          gang  audition  police fake
# 4796                    distrust  garage  identity crisis
# 4797                                                  NaN
# 4798            united states\umexico barrier  legs  arms
# 4799                                                  NaN
# 4800                 date  love at first sight  narration
# 4801                                                  NaN
# 4802                          obsession  camcorder  crush
# Length: 4803, dtype: object

# %%
keywords_df = keywords.str.split(",", expand=True)

# %%
keywords_df
# Out:
#                                  0                         1   \
# 0                     culture clash                    future
# 1                             ocean                drug abuse
# 2                               spy            based on novel
# 3                         dc comics             crime fighter
# 4                    based on novel                      mars
# 5                     dual identity                   amnesia
# 6                           hostage                     magic
# 7                      marvel comic                    sequel
# 8                             witch                     magic
# 9                         dc comics                 vigilante
# 10                 saving the world                 dc comics
# 11                          killing                undercover
# 12                            witch            fortune teller
# 13                            texas                     horse
# 14                 saving the world                 dc comics
# 15                   based on novel           fictional place
# 16                         new york                    shield
# 17                              sea                   captain
# 18                      time travel              time machine
# 19                       corruption                     elves
# 20                   loss of father                 vigilante
# 21                       robin hood                    archer
# 22                            elves                   dwarves
# 23                          england                   compass
# 24                    film business                screenplay
# 25                        shipwreck                   iceberg
# 26                        civil war                       war
# 27                            fight                 u.s. navy
# 28                          monster                       dna
# 29                              spy              secret agent
# ...                             ...                       ...
# 4773                     salesclerk                     loser
# 4774                          dream              prostitution
# 4775                     mumblecore                      None
# 4776                         office                      love
# 4777                                                     None
# 4778                        rampage                  massacre
# 4779                           moon                philosophy
# 4780                                                     None
# 4781                         dating                   divorce
# 4782                   christianity   father son relationship
# 4783                     possession                      None
# 4784                     mumblecore                      None
# 4785                                                     None
# 4786               independent film                      None
# 4787                      superhero                      None
# 4788                            gay              trailer park
# 4789                      addiction    recovering drug addict
# 4790                                                     None
# 4791                  home invasion                      None
# 4792                          japan                prostitute
# 4793                     confession                    hazing
# 4794                                                     None
# 4795                           gang                  audition
# 4796                       distrust                    garage
# 4797                                                     None
# 4798  united states\umexico barrier                      legs
# 4799                                                     None
# 4800                           date       love at first sight
# 4801                                                     None
# 4802                      obsession                 camcorder
#
#                                 2                             3   \
# 0                        space war                  space colony
# 1                    exotic island    east india trading company
# 2                     secret agent                        sequel
# 3                        terrorist               secret identity
# 4                        medallion                  space travel
# 5                        sandstorm            love of one's life
# 6                            horse                    fairy tale
# 7                        superhero           based on comic book
# 8                            broom          school of witchcraft
# 9                        superhero           based on comic book
# 10                 invulnerability                        sequel
# 11                    secret agent        british secret service
# 12                         bondage                 exotic island
# 13                        survivor                  texas ranger
# 14                       superhero           based on comic book
# 15     brother sister relationship                          lion
# 16                    marvel comic                     superhero
# 17                          mutiny                         sword
# 18                           alien   fictional government agency
# 19                         dwarves                          orcs
# 20                           serum                  marvel comic
# 21                          knight               sherwood forest
# 22                            orcs                        hobbit
# 23                      experiment                      lordship
# 24                   show business                   film making
# 25                            ship                         panic
# 26                    marvel comic                        sequel
# 27                    mind reading                     hong kong
# 28               tyrannosaurus rex                  velociraptor
# 29                       sociopath                        killer
# ...                            ...                           ...
# 4773           aftercreditsstinger                          None
# 4774                          None                          None
# 4775                          None                          None
# 4776              independent film                     secretary
# 4777                          None                          None
# 4778                 killing spree                          None
# 4779                       burglar                         texas
# 4780                          None                          None
# 4781                     sex scene                    sex comedy
# 4782                       georgia           ark of the covenant
# 4783                          None                          None
# 4784                          None                          None
# 4785                          None                          None
# 4786                          None                          None
# 4787                          None                          None
# 4788                   pop culture                   drug dealer
# 4789                 estranged son                          None
# 4790                          None                          None
# 4791                          None                          None
# 4792                         hotel                based on novel
# 4793                   gang member                        latino
# 4794                          None                          None
# 4795                   police fake                      homeless
# 4796               identity crisis                   time travel
# 4797                          None                          None
# 4798                          arms                   paper knife
# 4799                          None                          None
# 4800                     narration                 investigation
# 4801                          None                          None
# 4802                         crush                    dream girl
#
#                            4                        5   \
# 0                     society             space travel
# 1          love of one's life                  traitor
# 2                          mi   british secret service
# 3                     burglar            hostage drama
# 4                    princess                    alien
# 5                 forgiveness                   spider
# 6                     musical                 princess
# 7                      vision           superhero team
# 8                    wizardry               apparition
# 9                     revenge             super powers
# 10                  superhero      based on comic book
# 11                       None                     None
# 12                    monster                  captain
# 13                    partner                   outlaw
# 14                 superhuman           alien invasion
# 15                human being                   wretch
# 16        based on comic book           alien invasion
# 17             prime minister                  sailing
# 18          seeing the future         changing history
# 19     middle-earth (tolkien)                   hobbit
# 20      scientific experiment              spider bite
# 21              bow and arrow              middle ages
# 22                     dragon                   wizard
# 23                      uncle               polar bear
# 24              film producer            exotic island
# 25                    titanic              ocean liner
# 26                  superhero      based on comic book
# 27                     soccer                scientist
# 28                     island                   sequel
# 29                art gallery   british secret service
# ...                       ...                      ...
# 4773                     None                     None
# 4774                     None                     None
# 4775                     None                     None
# 4776               misogynist                     None
# 4777                     None                     None
# 4778                     None                     None
# 4779                    dream              atomic bomb
# 4780                     None                     None
# 4781     anti romantic comedy                     None
# 4782                 minister           christian film
# 4783                     None                     None
# 4784                     None                     None
# 4785                     None                     None
# 4786                     None                     None
# 4787                     None                     None
# 4788                   heroin                fetishism
# 4789                     None                     None
# 4790                     None                     None
# 4791                     None                     None
# 4792            hallucination                interview
# 4793                     lgbt          catholic priest
# 4794                     None                     None
# 4795                  actress                     None
# 4796             time machine              mathematics
# 4797                     None                     None
# 4798              guitar case                     None
# 4799                     None                     None
# 4800                     team            postal worker
# 4801                     None                     None
# 4802                     None                     None
#
#                                    6                            7   \
# 0                          futuristic                      romance
# 1                           shipwreck                 strong woman
# 2                      united kingdom                         None
# 3                           time bomb                  gotham city
# 4                           steampunk                      martian
# 5                              wretch            death of a friend
# 6                           animation                        tower
# 7                duringcreditsstinger    marvel cinematic universe
# 8                       teenage crush                     werewolf
# 9                          clark kent                  bruce wayne
# 10                         kryptonite                 super powers
# 11                               None                         None
# 12                          card game   east india trading company
# 13                             escape                       lawyer
# 14                             reboot                 super powers
# 15                       leap in time     matter of life and death
# 16                     superhero team          aftercreditsstinger
# 17                             silver                         ship
# 18                               None                         None
# 19                             dragon                       battle
# 20                   masked vigilante                       reboot
# 21                           medieval              king of england
# 22                  sword and sorcery                         None
# 23                             orphan                       animal
# 24                            monster                   indigenous
# 25                               epic        rich woman - poor man
# 26                               imax          aftercreditsstinger
# 27                      fictional war                        naval
# 28                           suspense                     disaster
# 29                    istanbul turkey                         imax
# ...                               ...                          ...
# 4773                             None                         None
# 4774                             None                         None
# 4775                             None                         None
# 4776                             None                         None
# 4777                             None                         None
# 4778                             None                         None
# 4779                             tent                    anarchist
# 4780                             None                         None
# 4781                             None                         None
# 4782                       repentance                         None
# 4783                             None                         None
# 4784                             None                         None
# 4785                             None                         None
# 4786                             None                         None
# 4787                             None                         None
# 4788                          spanner                   excrements
# 4789                             None                         None
# 4790                             None                         None
# 4791                             None                         None
# 4792                    investigation                       murder
# 4793   shakespeare's romeo and juliet                  latino lgbt
# 4794                             None                         None
# 4795                             None                         None
# 4796                 independent film                      paradox
# 4797                             None                         None
# 4798                             None                         None
# 4799                             None                         None
# 4800                             None                         None
# 4801                             None                         None
# 4802                             None                         None
#
#                                8                           9   ...     87  \
# 0                           space                       alien  ...   None
# 1                            ship                    alliance  ...   None
# 2                            None                        None  ...   None
# 3                       vigilante                    cover-up  ...   None
# 4                          escape        edgar rice burroughs  ...   None
# 5                        egomania                        sand  ...   None
# 6                    blonde woman                 selfishness  ...   None
# 7                               d                        None  ...   None
# 8                            None                        None  ...   None
# 9            dc extended universe                        None  ...   None
# 10            superhuman strength                  lex luthor  ...   None
# 11                           None                        None  ...   None
# 12                        compass                        ship  ...   None
# 13                          train                 lone ranger  ...   None
# 14           dc extended universe                        None  ...   None
# 15                          faith                       uncle  ...   None
# 16           duringcreditsstinger   marvel cinematic universe  ...   None
# 17                           duke                     mermaid  ...   None
# 18                           None                        None  ...   None
# 19            unlikely friendship                 epic battle  ...   None
# 20                   super powers         genetic engineering  ...   None
# 21                           None                        None  ...   None
# 22                           None                        None  ...   None
# 23     based on young adult novel                        None  ...   None
# 24                           ship                    dinosaur  ...   None
# 25                           love                    disaster  ...   None
# 26           duringcreditsstinger   marvel cinematic universe  ...   None
# 27                         armada                  battleship  ...   None
# 28                         escape                    dinosaur  ...   None
# 29                            uzi                  booby trap  ...   None
# ...                           ...                         ...  ...    ...
# 4773                         None                        None  ...   None
# 4774                         None                        None  ...   None
# 4775                         None                        None  ...   None
# 4776                         None                        None  ...   None
# 4777                         None                        None  ...   None
# 4778                         None                        None  ...   None
# 4779                    telescope                         ufo  ...   None
# 4780                         None                        None  ...   None
# 4781                         None                        None  ...   None
# 4782                         None                        None  ...   None
# 4783                         None                        None  ...   None
# 4784                         None                        None  ...   None
# 4785                         None                        None  ...   None
# 4786                         None                        None  ...   None
# 4787                         None                        None  ...   None
# 4788                      disgust                    dog dirt  ...   None
# 4789                         None                        None  ...   None
# 4790                         None                        None  ...   None
# 4791                         None                        None  ...   None
# 4792                     junkyard               interrogation  ...   None
# 4793              gang initiation                     gunplay  ...   None
# 4794                         None                        None  ...   None
# 4795                         None                        None  ...   None
# 4796       mechanical engineering                        None  ...   None
# 4797                         None                        None  ...   None
# 4798                         None                        None  ...   None
# 4799                         None                        None  ...   None
# 4800                         None                        None  ...   None
# 4801                         None                        None  ...   None
# 4802                         None                        None  ...   None
#
#         88    89    90    91    92    93    94    95    96
# 0     None  None  None  None  None  None  None  None  None
# 1     None  None  None  None  None  None  None  None  None
# 2     None  None  None  None  None  None  None  None  None
# 3     None  None  None  None  None  None  None  None  None
# 4     None  None  None  None  None  None  None  None  None
# 5     None  None  None  None  None  None  None  None  None
# 6     None  None  None  None  None  None  None  None  None
# 7     None  None  None  None  None  None  None  None  None
# 8     None  None  None  None  None  None  None  None  None
# 9     None  None  None  None  None  None  None  None  None
# 10    None  None  None  None  None  None  None  None  None
# 11    None  None  None  None  None  None  None  None  None
# 12    None  None  None  None  None  None  None  None  None
# 13    None  None  None  None  None  None  None  None  None
# 14    None  None  None  None  None  None  None  None  None
# 15    None  None  None  None  None  None  None  None  None
# 16    None  None  None  None  None  None  None  None  None
# 17    None  None  None  None  None  None  None  None  None
# 18    None  None  None  None  None  None  None  None  None
# 19    None  None  None  None  None  None  None  None  None
# 20    None  None  None  None  None  None  None  None  None
# 21    None  None  None  None  None  None  None  None  None
# 22    None  None  None  None  None  None  None  None  None
# 23    None  None  None  None  None  None  None  None  None
# 24    None  None  None  None  None  None  None  None  None
# 25    None  None  None  None  None  None  None  None  None
# 26    None  None  None  None  None  None  None  None  None
# 27    None  None  None  None  None  None  None  None  None
# 28    None  None  None  None  None  None  None  None  None
# 29    None  None  None  None  None  None  None  None  None
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 4773  None  None  None  None  None  None  None  None  None
# 4774  None  None  None  None  None  None  None  None  None
# 4775  None  None  None  None  None  None  None  None  None
# 4776  None  None  None  None  None  None  None  None  None
# 4777  None  None  None  None  None  None  None  None  None
# 4778  None  None  None  None  None  None  None  None  None
# 4779  None  None  None  None  None  None  None  None  None
# 4780  None  None  None  None  None  None  None  None  None
# 4781  None  None  None  None  None  None  None  None  None
# 4782  None  None  None  None  None  None  None  None  None
# 4783  None  None  None  None  None  None  None  None  None
# 4784  None  None  None  None  None  None  None  None  None
# 4785  None  None  None  None  None  None  None  None  None
# 4786  None  None  None  None  None  None  None  None  None
# 4787  None  None  None  None  None  None  None  None  None
# 4788  None  None  None  None  None  None  None  None  None
# 4789  None  None  None  None  None  None  None  None  None
# 4790  None  None  None  None  None  None  None  None  None
# 4791  None  None  None  None  None  None  None  None  None
# 4792  None  None  None  None  None  None  None  None  None
# 4793  None  None  None  None  None  None  None  None  None
# 4794  None  None  None  None  None  None  None  None  None
# 4795  None  None  None  None  None  None  None  None  None
# 4796  None  None  None  None  None  None  None  None  None
# 4797  None  None  None  None  None  None  None  None  None
# 4798  None  None  None  None  None  None  None  None  None
# 4799  None  None  None  None  None  None  None  None  None
# 4800  None  None  None  None  None  None  None  None  None
# 4801  None  None  None  None  None  None  None  None  None
# 4802  None  None  None  None  None  None  None  None  None
#
# [4803 rows x 97 columns]

# %%
first3 = keywords_df[[0,1,2]]

# %%
keywords = first3[0]+", "+first3[1]+", "+first3[2]
movies["keywordsString"] = keywords

# %%
movies.head()
# Out:
#       budget                                       genres  \
# 0  237000000  Action, Adventure, Fantasy, Science Fiction
# 1  300000000                   Adventure, Fantasy, Action
# 2  245000000                     Action, Adventure, Crime
# 3  250000000               Action, Crime, Drama, Thriller
# 4  260000000           Action, Adventure, Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                    ...                   release_date     revenue  runtime  \
# 0                  ...                     2009-12-10  2787965087    162.0
# 1                  ...                     2007-05-19   961000000    169.0
# 2                  ...                     2015-10-26   880674609    148.0
# 3                  ...                     2012-07-16  1084939099    165.0
# 4                  ...                     2012-03-07   284139100    132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average  vote_count  \
# 0                                    Avatar          7.2       11800
# 1  Pirates of the Caribbean: At World's End          6.9        4500
# 2                                   Spectre          6.3        4466
# 3                     The Dark Knight Rises          7.6        9106
# 4                               John Carter          6.1        2124
#
#                           keywordsString
# 0     culture clash,  future,  space war
# 1     ocean,  drug abuse,  exotic island
# 2    spy,  based on novel,  secret agent
# 3  dc comics,  crime fighter,  terrorist
# 4      based on novel,  mars,  medallion
#
# [5 rows x 21 columns]
